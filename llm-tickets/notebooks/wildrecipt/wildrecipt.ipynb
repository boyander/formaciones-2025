# %%
from datasets import load_dataset

ds = load_dataset("pontusnorman123/wildreceipt")
# Out:
# README.md:   0%|          | 0.00/1.31k [00:00<?, ?B/s]
# train-00000-of-00002.parquet:   0%|          | 0.00/450M [00:00<?, ?B/s]
# train-00001-of-00002.parquet:   0%|          | 0.00/490M [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/427M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1267 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/472 [00:00<?, ? examples/s]

# %%
ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'id', 'words', 'bboxes', 'ner_tags'],
#         num_rows: 1267
#     })
#     test: Dataset({
#         features: ['image', 'id', 'words', 'bboxes', 'ner_tags'],
#         num_rows: 472
#     })
# })

# %%
sample = ds["train"][0]
sample["image"]
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1600x1200>

# %%
from transformers import LayoutLMForTokenClassification, LayoutLMTokenizer
from PIL import Image

# Load pre-trained model and tokenizer
model = LayoutLMForTokenClassification.from_pretrained("microsoft/layoutlm-base-uncased")
tokenizer = LayoutLMTokenizer.from_pretrained("microsoft/layoutlm-base-uncased")
# Out:
# config.json:   0%|          | 0.00/606 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/451M [00:00<?, ?B/s]
# Some weights of LayoutLMForTokenClassification were not initialized from the model checkpoint at microsoft/layoutlm-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# tokenizer_config.json:   0%|          | 0.00/170 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %%
image = Image.open("../../ticket.jpg").convert("RGB")
encoding = tokenizer(image, return_tensors="pt")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 2
#       1 image = Image.open("../../ticket.jpg").convert("RGB")
# ----> 2 encoding = tokenizer(image, return_tensors="pt")
#
# File ~/KIRBIC/content-talleres-jornadas/.venv/lib/python3.9/site-packages/transformers/tokenization_utils_base.py:2867, in PreTrainedTokenizerBase.__call__(self, text, text_pair, text_target, text_pair_target, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    2865     if not self._in_target_context_manager:
#    2866         self._switch_to_input_mode()
# -> 2867     encodings = self._call_one(text=text, text_pair=text_pair, **all_kwargs)
#    2868 if text_target is not None:
#    2869     self._switch_to_target_mode()
#
# File ~/KIRBIC/content-talleres-jornadas/.venv/lib/python3.9/site-packages/transformers/tokenization_utils_base.py:2927, in PreTrainedTokenizerBase._call_one(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, split_special_tokens, **kwargs)
#    2924         return False
#    2926 if not _is_valid_text_input(text):
# -> 2927     raise ValueError(
#    2928         "text input must be of type `str` (single example), `List[str]` (batch or single pretokenized example) "
#    2929         "or `List[List[str]]` (batch of pretokenized examples)."
#    2930     )
#    2932 if text_pair is not None and not _is_valid_text_input(text_pair):
#    2933     raise ValueError(
#    2934         "text input must be of type `str` (single example), `List[str]` (batch or single pretokenized example) "
#    2935         "or `List[List[str]]` (batch of pretokenized examples)."
#    2936     )
#
# ValueError: text input must be of type `str` (single example), `List[str]` (batch or single pretokenized example) or `List[List[str]]` (batch of pretokenized examples).
